# %%
from life_well_main import clean_data
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
filepath = '../data/wellbeing-lifestyle-cs1.csv'
df = pd.read_csv(filepath)
mr_clean = clean_data(df)

# %%
corrs = mr_clean.corr()
fig = plt.figure(figsize=(17, 10))
sns.heatmap(corrs, annot=True);

# %%
cols1 = ['fruits_veggies', 'daily_stress', 'places_visited', 'core_circle',
        'supporting_others', 'social_network', 'achievement', 'donation',
        'todo_completed', 'flow', 'bal_score']
       
cols2 = ['sleep_hours', 'lost_vacation', 'daily_shouting', 'sufficient_income',
       'personal_awards', 'time_for_passion', 'daily_meditation', 'bmi_range',
       'daily_steps', 'live_vision', 'bal_score']

# %%
#fig = plt.figure(figsize=(18,10))
sns.pairplot(mr_clean[cols1], kind='scatter', diag_kind='kde');

# %%
#fig = plt.figure(figsize=(18,10))
sns.pairplot(mr_clean[cols2], kind='scatter', diag_kind='kde');
